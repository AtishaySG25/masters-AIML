# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: psycopg in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from -r requirements.txt (line 1)) (3.1.17)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from -r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: apache-airflow in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from -r requirements.txt (line 3)) (2.8.0)
# Requirement already satisfied: datetime in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from -r requirements.txt (line 4)) (5.4)
# Requirement already satisfied: requests in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from -r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: pandasql in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from -r requirements.txt (line 6)) (0.7.3)
# Requirement already satisfied: urllib3 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from -r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: traceback2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from -r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: typing-extensions>=4.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from psycopg->-r requirements.txt (line 1)) (4.10.0)
# Requirement already satisfied: tzdata in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from psycopg->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from pandas->-r requirements.txt (line 2)) (1.23.5)
# Requirement already satisfied: alembic<2.0,>=1.6.3 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: argcomplete>=1.10 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: asgiref in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.7.2)
# Requirement already satisfied: attrs>=22.1.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: blinker in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.6.2)
# Requirement already satisfied: colorlog<5.0,>=4.0.2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: configupdater>=3.1.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.2)
# Requirement already satisfied: connexion[flask]<3.0,>=2.10.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.14.2)
# Requirement already satisfied: cron-descriptor>=1.2.24 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: croniter>=0.3.17 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: cryptography>=0.9.3 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (41.0.7)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.2.14)
# Requirement already satisfied: dill>=0.2.2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.3.7)
# Requirement already satisfied: flask<2.3,>=2.2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.2.5)
# Requirement already satisfied: flask-appbuilder==4.3.10 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (4.3.10)
# Requirement already satisfied: flask-caching>=1.5.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: flask-login>=0.6.2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.6.3)
# Requirement already satisfied: flask-session>=0.4.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.5.0)
# Requirement already satisfied: flask-wtf>=0.15 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: fsspec>=2023.10.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2023.12.2)
# Requirement already satisfied: google-re2>=1.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.1)
# Requirement already satisfied: graphviz>=0.12 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.20.1)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: httpx in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.26.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (4.19.0)
# Requirement already satisfied: lazy-object-proxy in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.10.0)
# Requirement already satisfied: linkify-it-py>=2.0.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.12.2)
# Requirement already satisfied: markdown>=3.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.5.1)
# Requirement already satisfied: markdown-it-py>=2.1.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: markupsafe>=1.1.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: opentelemetry-api>=1.15.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: opentelemetry-exporter-otlp in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: packaging>=14.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (23.2)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: pendulum<3.0,>=2.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: pluggy>=1.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: psutil>=4.2.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (5.9.0)
# Requirement already satisfied: pydantic>=2.3.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.5.3)
# Requirement already satisfied: pygments>=2.0.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.16.1)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.8.0)
# Requirement already satisfied: python-daemon>=3.0.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: python-nvd3>=0.15.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.15.0)
# Requirement already satisfied: python-slugify>=5.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (8.0.1)
# Requirement already satisfied: rfc3339-validator>=0.1.4 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: rich>=12.4.4 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (13.5.2)
# Requirement already satisfied: rich-argparse>=1.0.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: setproctitle>=1.1.8 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4.28 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.4.51)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: tenacity!=8.2.0,>=6.2.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (8.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: unicodecsv>=0.14.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.14.1)
# Requirement already satisfied: universal-pathlib>=0.1.4 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: werkzeug<3,>=2.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: apache-airflow-providers-common-sql in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (1.10.0)
# Requirement already satisfied: apache-airflow-providers-ftp in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.7.0)
# Requirement already satisfied: apache-airflow-providers-http in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: apache-airflow-providers-imap in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: apache-airflow-providers-sqlite in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow->-r requirements.txt (line 3)) (3.7.0)
# Requirement already satisfied: apispec[yaml]<7,>=6.0.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (6.4.0)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: click<9,>=8 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (8.1.6)
# Requirement already satisfied: email-validator<2,>=1.0.5 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: Flask-Babel<3,>=1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: Flask-Limiter<4,>3 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (2.5.1)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (4.6.0)
# Requirement already satisfied: marshmallow<4,>=3.18.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (3.20.2)
# Requirement already satisfied: marshmallow-sqlalchemy<0.27.0,>=0.22.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (0.26.1)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (0.41.1)
# Requirement already satisfied: WTForms<4 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: zope.interface in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from datetime->-r requirements.txt (line 4)) (6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from requests->-r requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from requests->-r requirements.txt (line 5)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from requests->-r requirements.txt (line 5)) (2023.7.22)
# Requirement already satisfied: linecache2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from traceback2->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: Mako in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from alembic<2.0,>=1.6.3->apache-airflow->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: clickclick<21,>=1.2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow->-r requirements.txt (line 3)) (20.10.2)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow->-r requirements.txt (line 3)) (6.0.1)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow->-r requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from cryptography>=0.9.3->apache-airflow->-r requirements.txt (line 3)) (1.15.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from deprecated>=1.2.13->apache-airflow->-r requirements.txt (line 3)) (1.14.1)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask<2.3,>=2.2->apache-airflow->-r requirements.txt (line 3)) (6.8.0)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from flask-caching>=1.5.0->apache-airflow->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from jsonschema>=4.18.0->apache-airflow->-r requirements.txt (line 3)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from jsonschema>=4.18.0->apache-airflow->-r requirements.txt (line 3)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from jsonschema>=4.18.0->apache-airflow->-r requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: uc-micro-py in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from linkify-it-py>=2.0.0->apache-airflow->-r requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from markdown-it-py>=2.1.0->apache-airflow->-r requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: pytzdata>=2020.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from pendulum<3.0,>=2.0->apache-airflow->-r requirements.txt (line 3)) (2020.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from pydantic>=2.3.0->apache-airflow->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from pydantic>=2.3.0->apache-airflow->-r requirements.txt (line 3)) (2.14.6)
# Requirement already satisfied: docutils in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from python-daemon>=3.0.0->apache-airflow->-r requirements.txt (line 3)) (0.20.1)
# Requirement already satisfied: setuptools>=62.4.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from python-daemon>=3.0.0->apache-airflow->-r requirements.txt (line 3)) (68.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from python-slugify>=5.0->apache-airflow->-r requirements.txt (line 3)) (1.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from sqlalchemy<2.0,>=1.4.28->apache-airflow->-r requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: sqlparse>=0.4.2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow-providers-common-sql->apache-airflow->-r requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: aiohttp in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow-providers-http->apache-airflow->-r requirements.txt (line 3)) (3.9.1)
# Requirement already satisfied: requests_toolbelt in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from apache-airflow-providers-http->apache-airflow->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: anyio in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from httpx->apache-airflow->-r requirements.txt (line 3)) (3.7.1)
# Requirement already satisfied: httpcore==1.* in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from httpx->apache-airflow->-r requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from httpx->apache-airflow->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from httpcore==1.*->httpx->apache-airflow->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.22.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.22.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: backoff<3.0.0,>=1.10.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (1.62.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (1.59.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.22.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: opentelemetry-proto==1.22.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: opentelemetry-sdk~=1.22.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (1.22.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-proto==1.22.0->opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: pycparser in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow->-r requirements.txt (line 3)) (2.21)
# Requirement already satisfied: dnspython>=1.15.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (2.4.2)
# Requirement already satisfied: Babel>=2.3 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (2.14.0)
# Requirement already satisfied: limits>=2.8 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (3.7.0)
# Requirement already satisfied: ordered-set<5,>4 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (4.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from importlib-metadata>=3.6.0->flask<2.3,>=2.2->apache-airflow->-r requirements.txt (line 3)) (3.16.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow->-r requirements.txt (line 3)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow->-r requirements.txt (line 3)) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from aiohttp->apache-airflow-providers-http->apache-airflow->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: exceptiongroup in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from anyio->httpx->apache-airflow->-r requirements.txt (line 3)) (1.1.3)
# Requirement already satisfied: importlib-resources>=1.3 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from limits>=2.8->Flask-Limiter<4,>3->flask-appbuilder==4.3.10->apache-airflow->-r requirements.txt (line 3)) (6.0.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.43b0 in c:\users\atishay sg\anaconda3\envs\aimlsem1\lib\site-packages (from opentelemetry-sdk~=1.22.0->opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow->-r requirements.txt (line 3)) (0.43b0)

# %%
##Load libraries
import psycopg2
import os
import traceback
import logging
import pandas as pd
import urllib.request

logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s:%(funcName)s:%(levelname)s:%(message)s')

# %%
# postgres_host = os.environ.get('postgres_host')
# postgres_database = os.environ.get('postgres_database')
# postgres_user = os.environ.get('postgres_user')
# # postgres_password = os.environ.get('sayonee650')
# postgres_password = 'sayonee650'
# postgres_port = os.environ.get('postgres_port')
# dest_folder = os.environ.get('dest_folder')

# url = "https://raw.githubusercontent.com/dogukannulu/datasets/master/Churn_Modelling.csv"
# destination_path = f'{dest_folder}/churn_modelling.csv'

# try:
#     conn = psycopg2.connect(
#         host=postgres_host,
#         database=postgres_database,
#         user=postgres_user,
#         password=postgres_password,
#         port=postgres_port
#     )
#     cur = conn.cursor()
#     logging.info('Postgres server connection is successful')
# except Exception as e:
#     traceback.print_exc()
#     logging.error("Couldn't create the Postgres connection")

# %%
# dest_folder = os.environ.get('dest_folder')
# url = "https://raw.githubusercontent.com/dogukannulu/datasets/master/Churn_Modelling.csv"
# destination_path = f'{dest_folder}/churn_modelling.csv'

try:
    connection = psycopg2.connect(
        user="Atishay",
        password="sayonee650",
        host="localhost",
        dbname="postgres"
        # port="5432",
        # database="AIML_2024"
    )
 

    connection.autocommit = True
    cursor = connection.cursor()
    print("Connected to the database")
    # Now you can perform operations on the database using the connection

except (Exception, psycopg2.Error) as error:
    print(f"Error while connecting to PostgreSQL: {error}")
# Out:
# Error while connecting to PostgreSQL: connection to server at "localhost" (::1), port 5432 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5432 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?

# %%
def download_file_from_url(url: str, dest_folder: str):
    """
    Download a file from a specific URL and download to the local direcory
    """
    if not os.path.exists(str(dest_folder)):
        os.makedirs(str(dest_folder))  # create folder if it does not exist

    try:
        urllib.request.urlretrieve(url, destination_path)
        logging.info('csv file downloaded successfully to the working directory')
    except Exception as e:
        logging.error(f'Error while downloading the csv file due to: {e}')
        traceback.print_exc()

# %%
def create_postgres_table():
    """
    Create the Postgres table with a desired schema
    """
    try:
        cur.execute("""CREATE TABLE IF NOT EXISTS churn_modelling (RowNumber INTEGER PRIMARY KEY, CustomerId INTEGER, 
        Surname VARCHAR(50), CreditScore INTEGER, Geography VARCHAR(50), Gender VARCHAR(20), Age INTEGER, 
        Tenure INTEGER, Balance FLOAT, NumOfProducts INTEGER, HasCrCard INTEGER, IsActiveMember INTEGER, EstimatedSalary FLOAT, Exited INTEGER)""")
        
        logging.info(' New table churn_modelling created successfully to postgres server')
    except:
        logging.warning(' Check if the table churn_modelling exists')

# %%
def write_to_postgres():
    """
    Create the dataframe and write to Postgres table if it doesn't already exist
    """
    df = pd.read_csv(f'{dest_folder}/churn_modelling.csv')
    inserted_row_count = 0

    for _, row in df.iterrows():
        count_query = f"""SELECT COUNT(*) FROM churn_modelling WHERE RowNumber = {row['RowNumber']}"""
        cur.execute(count_query)
        result = cur.fetchone()
        
        if result[0] == 0:
            inserted_row_count += 1
            cur.execute("""INSERT INTO churn_modelling (RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, 
            Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited) VALUES (%s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s)""", 
            (int(row[0]), int(row[1]), str(row[2]), int(row[3]), str(row[4]), str(row[5]), int(row[6]), int(row[7]), float(row[8]), int(row[9]), int(row[10]), int(row[11]), float(row[12]), int(row[13])))

    logging.info(f' {inserted_row_count} rows from csv file inserted into churn_modelling table successfully')
